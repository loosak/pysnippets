# %% [markdown]
# # Moon Phase

# %%
import datetime as dt

def julian(year, month, day):
    a = (14 - month) / 12.0
    y = year + 4800 - a
    m = (12 * a) - 3 + month
    return (
        day + (153 * m + 2) / 5.0 + (365 * y) + y / 4.0 - y / 100.0 + y / 400.0 - 32045
    )

moon_phase = {
    1.84566:  "🌑",  # new
    5.53699:  "🌒",  # waxing crescent
    9.22831:  "🌓",  # first quarter
    12.91963: "🌔",  # waxing gibbous
    16.61096: "🌕",  # full
    20.30228: "🌖",  # waning gibbous
    23.99361: "🌗",  # last quarter
    27.68493: "🌘",  # waning crescent
    27.68494: "🌑",  # new
}

now = dt.datetime.now()
phase = (julian(now.year, now.month, now.day) - julian(2000, 1, 6)) % 29.530588853
moon_phase.get([k for k in moon_phase.keys() if phase < k][0])
# Out:
# '🌒'

# %%
moon_phase.get(list(filter(lambda x: phase<x,moon_phase))[0])
# Out:
# '🌗'

# %%
def greet_me(**kwargs):
    for key, value in kwargs.items():
        print(f"{key} = {value}")
        
greet_me(name1="nodes",name2="yesod")
# Out:
# name1 = nodes
# name2 = yesod

# %% [markdown]
# # Merge Dictionaries
# The `.update()` method is called from the primary dictionary and accepts another dictionary as an argument.

# %%
d1 = { "first_name": "Jonathan",
            "last_name": "Hsu" 
}

d1.update({"first_name": "Jet", "age": 15})
d1
# Out:
# {'first_name': 'Jet', 'last_name': 'Hsu', 'age': 15}

# %% [markdown]
# ##  double-asterisk operator
# An alternative is the double-asterisk operator, which is used to unpack dictionaries:

# %%
d2 = { "first_name": "Li", 
       "age": 25 
}

{ **d1, **d2 }
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-6292b3daf289> in <module>
#       3 }
#       4
# ----> 5 { **d1, **d2 }
#
# NameError: name 'd1' is not defined

# %% [markdown]
# ## Union Operators To dict
# [PEP 584 -- Add Union Operators To dict](https://www.python.org/dev/peps/pep-0584/)
#
# Remember, these operators will only be available in Python 3.9 and above so make sure you add the appropriate version validation to your code.

# %%
d1 = { "first_name": "Jonathan", "last_name": "Hsu" }
d2 = { "first_name": "Jet", "age": 15 }
d3 = d1 | d2
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-97-8fad9e48e8be> in <module>
#       1 d1 = { "first_name": "Jonathan", "last_name": "Hsu" }
#       2 d2 = { "first_name": "Jet", "age": 15 }
# ----> 3 d3 = d1 | d2
#
# TypeError: unsupported operand type(s) for |: 'dict' and 'dict'

# %%
myDict = { "first_name": "Jonathan", "last_name": "Hsu" }
myDict |= {"first_name": "Jet", "age": 15}
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-98-b3f54ea34420> in <module>
#       1 myDict = { "first_name": "Jonathan", "last_name": "Hsu" }
# ----> 2 myDict |= {"first_name": "Jet", "age": 15}
#
# TypeError: unsupported operand type(s) for |=: 'dict' and 'dict'

# %% [markdown]
# # math
#
# $$
# f(x) = {\frac {\sin(x)}{(x)}}
# $$

# %%
# Configure plotting in Jupyter
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams.update({
    'figure.figsize': (9, 9),
})

"""
    'axes.spines.right': False,
    'axes.spines.left': False,
    'axes.spines.top': False,
    'axes.spines.bottom': False})
"""
# Out:
# "\n    'axes.spines.right': False,\n    'axes.spines.left': False,\n    'axes.spines.top': False,\n    'axes.spines.bottom': False})\n"

# %%
import numpy as np
x = np.linspace(-6*np.pi,6*np.pi)
print(len(x))
f = x*x
plt.plot(x,f);
# Out:
# 50

# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
plt.rcParams.update({'figure.figsize': (12, 12),})


x = np.linspace(-6*np.pi, 6*np.pi, 6*32)
f = np.sin(x)/x
plt.plot(x,f, label=r'$f(x) = {\frac {\sin(x)}{(x)}}$')
matplotlib.rcParams['font.size'] = '18.0'
#plt.title(r'$f(x) = {\frac {sin(x)}{(x)}}$')
plt.legend(frameon=False)
plt.plot((x[0],x[-1]),(0,0),    '--', color='grey', linewidth=1.2)    # x = 0
plt.plot((0,0),(min(f),max(f)), '--', color='grey', linewidth=1.2)    # y = 0
plt.grid();

# %%
def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = int(np.round(2 * value / np.pi))
    if N == 0:
        return "0"
    elif N == 1:
        return r"$\pi/2$"
    elif N == 2:
        return r"$\pi$"
    elif N % 2 > 0:
        return r"${0}\pi/2$".format(N)
    else:
        return r"${0}\pi$".format(N // 2)

format_func(10,1)
# Out:
# '$3\\pi$'

# %%
format = {
    0:  '0',
    1:  r'$\pi/2$',
    2:  r'$\pi$',
}
format
# Out:
# {0: '0', 1: '$\\pi/2$', 2: '$\\pi$'}

# %%
    
fig,ax = plt.subplots()  
ax.grid()
ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax.plot(x,f, linewidth=4, label=r'$f(x) = {\frac {\sin(x)}{(x)}}$')
plt.rcParams.update({'font.size': 18.0})
plt.rcParams.update({'figure.figsize': (12, 12)})

plt.legend(frameon=False)

# Draws the red vertical line in graph at x=0 
plt.axvline(x=0, linewidth=1.8, color = 'grey') 
plt.axhline(y=0, linewidth=1.8, color = 'grey') 
plt.xkcd(scale=1, length=200, randomness=4);

# %%
plt.Line2D([0,1],[0,1])

# %%
x = np.linspace(-5,5,100)
print(len(x))
f = 1/x
plt.plot(x,f, '-', linewidth=2)
# Out:
# 100

# %%
x = np.linspace(-5,5,100)
f = 1/(x*x)
plt.plot(x,f, '-', linewidth=2, )

# %%
x = np.linspace(-5*np.pi,5*np.pi,100)
f = x*np.sin(x)
plt.plot(x,f, '-', linewidth=2, )
