# %% [markdown]
# # Sine and Cosine Functions
#
# [8.1 Graphs of the Sine and Cosine Functions](https://openstax.org/books/algebra-and-trigonometry/pages/8-1-graphs-of-the-sine-and-cosine-functions)
#
# <table data-id="Table_06_01_01" summary="Table 1 "><tbody>
# <tr>
# <td data-align="center"><strong><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1186-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mi>x</mi></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mi>x</mi></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25943" style="width: 0.76em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.897em, 1000.49em, 2.654em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-25944"><span class="semantics" id="MathJax-Span-25945"><span class="mrow" id="MathJax-Span-25946"><span class="mi" id="MathJax-Span-25947" style="font-family: STIXGeneral-Italic;">𝑥</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 0.718em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mi>x</mi></mrow><annotation-xml encoding="MathML-Content"><mi>x</mi></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1186"><math display="inline"><semantics><mrow>
#  <mi>x</mi>
# </mrow><annotation-xml encoding="MathML-Content"><mi>x</mi></annotation-xml></semantics></math></script></strong></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1187-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mn>0</mn></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mn>0</mn></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25948" style="width: 0.76em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.68em, 1000.54em, 2.654em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-25949"><span class="semantics" id="MathJax-Span-25950"><span class="mrow" id="MathJax-Span-25951"><span class="mn" id="MathJax-Span-25952" style="font-family: STIXGeneral-Regular;">0</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 1.075em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mn>0</mn></mrow><annotation-xml encoding="MathML-Content"><mn>0</mn></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1187"><math display="inline"><semantics><mrow>
#  <mn>0</mn>
# </mrow><annotation-xml encoding="MathML-Content"><mn>0</mn></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1188-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mi>&amp;#x3C0;</mi><mn>6</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mi>π</mi><mn>6</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25953" style="width: 1.031em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.76em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.301em, 1000.76em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-25954"><span class="semantics" id="MathJax-Span-25955"><span class="mrow" id="MathJax-Span-25956"><span class="mrow" id="MathJax-Span-25957"><span class="mfrac" id="MathJax-Span-25958"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.52em, 1000.38em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.214em;"><span class="mi" id="MathJax-Span-25959" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-25960" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">6</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.54em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.646em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mi>π</mi><mn>6</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mi>π</mi><mn>6</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1188"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>6</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>6</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1189-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mi>&amp;#x3C0;</mi><mn>4</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mi>π</mi><mn>4</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25961" style="width: 1.031em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.76em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.301em, 1000.76em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-25962"><span class="semantics" id="MathJax-Span-25963"><span class="mrow" id="MathJax-Span-25964"><span class="mrow" id="MathJax-Span-25965"><span class="mfrac" id="MathJax-Span-25966"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.52em, 1000.38em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.214em;"><span class="mi" id="MathJax-Span-25967" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-25968" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">4</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.54em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.646em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mi>π</mi><mn>4</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mi>π</mi><mn>4</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1189"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>4</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>4</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1190-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mi>&amp;#x3C0;</mi><mn>3</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mi>π</mi><mn>3</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25969" style="width: 1.031em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.76em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.301em, 1000.76em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-25970"><span class="semantics" id="MathJax-Span-25971"><span class="mrow" id="MathJax-Span-25972"><span class="mrow" id="MathJax-Span-25973"><span class="mfrac" id="MathJax-Span-25974"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.52em, 1000.38em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.214em;"><span class="mi" id="MathJax-Span-25975" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-25976" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">3</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.54em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.646em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mi>π</mi><mn>3</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mi>π</mi><mn>3</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1190"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>3</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>3</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1191-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mi>&amp;#x3C0;</mi><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mi>π</mi><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25977" style="width: 1.031em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.76em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.301em, 1000.76em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-25978"><span class="semantics" id="MathJax-Span-25979"><span class="mrow" id="MathJax-Span-25980"><span class="mrow" id="MathJax-Span-25981"><span class="mfrac" id="MathJax-Span-25982"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.52em, 1000.38em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.214em;"><span class="mi" id="MathJax-Span-25983" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-25984" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.54em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.646em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mi>π</mi><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mi>π</mi><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1191"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mi>π</mi>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1192-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mrow><mn>2</mn><mi>&amp;#x3C0;</mi></mrow><mn>3</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><mn>2</mn><mi>π</mi></mrow><mn>3</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25985" style="width: 1.464em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.085em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.085em, 1001.09em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-25986"><span class="semantics" id="MathJax-Span-25987"><span class="mrow" id="MathJax-Span-25988"><span class="mrow" id="MathJax-Span-25989"><span class="mfrac" id="MathJax-Span-25990"><span style="display: inline-block; position: relative; width: 0.869em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.358em, 1000.76em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.376em;"><span class="mrow" id="MathJax-Span-25991"><span class="mn" id="MathJax-Span-25992" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">2</span><span class="mi" id="MathJax-Span-25993" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-25994" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">3</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.87em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.869em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mrow><mn>2</mn><mi>π</mi></mrow><mn>3</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><mn>2</mn><mi>π</mi></mrow><mn>3</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1192"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <mn>2</mn><mi>π</mi>
#    </mrow>
#    <mn>3</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <mn>2</mn><mi>π</mi>
#    </mrow>
#    <mn>3</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1193-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mrow><mn>3</mn><mi>&amp;#x3C0;</mi></mrow><mn>4</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><mn>3</mn><mi>π</mi></mrow><mn>4</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-25995" style="width: 1.464em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.085em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.085em, 1001.09em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-25996"><span class="semantics" id="MathJax-Span-25997"><span class="mrow" id="MathJax-Span-25998"><span class="mrow" id="MathJax-Span-25999"><span class="mfrac" id="MathJax-Span-26000"><span style="display: inline-block; position: relative; width: 0.869em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.358em, 1000.76em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.376em;"><span class="mrow" id="MathJax-Span-26001"><span class="mn" id="MathJax-Span-26002" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">3</span><span class="mi" id="MathJax-Span-26003" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-26004" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">4</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.87em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.869em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mrow><mn>3</mn><mi>π</mi></mrow><mn>4</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><mn>3</mn><mi>π</mi></mrow><mn>4</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1193"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <mn>3</mn><mi>π</mi>
#    </mrow>
#    <mn>4</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <mn>3</mn><mi>π</mi>
#    </mrow>
#    <mn>4</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1194-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mrow><mn>5</mn><mi>&amp;#x3C0;</mi></mrow><mn>6</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><mn>5</mn><mi>π</mi></mrow><mn>6</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26005" style="width: 1.464em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.085em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.085em, 1001.09em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26006"><span class="semantics" id="MathJax-Span-26007"><span class="mrow" id="MathJax-Span-26008"><span class="mrow" id="MathJax-Span-26009"><span class="mfrac" id="MathJax-Span-26010"><span style="display: inline-block; position: relative; width: 0.869em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.358em, 1000.76em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.376em;"><span class="mrow" id="MathJax-Span-26011"><span class="mn" id="MathJax-Span-26012" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">5</span><span class="mi" id="MathJax-Span-26013" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-26014" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">6</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.87em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.869em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mrow><mn>5</mn><mi>π</mi></mrow><mn>6</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><mn>5</mn><mi>π</mi></mrow><mn>6</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1194"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <mn>5</mn><mi>π</mi>
#    </mrow>
#    <mn>6</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <mn>5</mn><mi>π</mi>
#    </mrow>
#    <mn>6</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1195-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mi>&amp;#x3C0;</mi></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mi>π</mi></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26015" style="width: 0.76em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.897em, 1000.54em, 2.654em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-26016"><span class="semantics" id="MathJax-Span-26017"><span class="mrow" id="MathJax-Span-26018"><span class="mi" id="MathJax-Span-26019" style="font-family: STIXGeneral-Italic;">𝜋<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 0.718em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mi>π</mi></mrow><annotation-xml encoding="MathML-Content"><mi>π</mi></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1195"><math display="inline"><semantics><mrow>
#  <mi>π</mi>
# </mrow><annotation-xml encoding="MathML-Content"><mi>π</mi></annotation-xml></semantics></math></script></td>
# </tr>
# <tr>
# <td data-align="center"><strong><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1196-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mi>sin</mi><mrow><mo>(</mo><mi>x</mi><mo>)</mo></mrow></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mi>sin</mi><mrow><mo>(</mo><mi>x</mi><mo>)</mo></mrow></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26020" style="width: 3.358em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.546em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.626em, 1002.49em, 2.817em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-26021"><span class="semantics" id="MathJax-Span-26022"><span class="mrow" id="MathJax-Span-26023"><span class="mrow" id="MathJax-Span-26024"><span class="mi" id="MathJax-Span-26025" style="font-family: STIXGeneral-Regular;">sin</span><span class="mrow" id="MathJax-Span-26026" style="padding-left: 0.165em;"><span class="mo" id="MathJax-Span-26027" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-26028" style="font-family: STIXGeneral-Italic;">𝑥</span><span class="mo" id="MathJax-Span-26029" style="font-family: STIXGeneral-Regular;">)</span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.289em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mi>sin</mi><mrow><mo>(</mo><mi>x</mi><mo>)</mo></mrow></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mi>sin</mi><mrow><mo>(</mo><mi>x</mi><mo>)</mo></mrow></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1196"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mi>sin</mi><mrow><mo>(</mo>
#    <mi>x</mi>
#   <mo>)</mo></mrow>
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mi>sin</mi><mrow><mo>(</mo>
#    <mi>x</mi>
#   <mo>)</mo></mrow>
#  </mrow></annotation-xml></semantics></math></script></strong></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1197-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mn>0</mn></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mn>0</mn></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26030" style="width: 0.76em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.68em, 1000.54em, 2.654em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-26031"><span class="semantics" id="MathJax-Span-26032"><span class="mrow" id="MathJax-Span-26033"><span class="mn" id="MathJax-Span-26034" style="font-family: STIXGeneral-Regular;">0</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 1.075em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mn>0</mn></mrow><annotation-xml encoding="MathML-Content"><mn>0</mn></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1197"><math display="inline"><semantics><mrow>
#  <mn>0</mn>
# </mrow><annotation-xml encoding="MathML-Content"><mn>0</mn></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1198-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26035" style="width: 0.923em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.706em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.139em, 1000.71em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26036"><span class="semantics" id="MathJax-Span-26037"><span class="mrow" id="MathJax-Span-26038"><span class="mrow" id="MathJax-Span-26039"><span class="mfrac" id="MathJax-Span-26040"><span style="display: inline-block; position: relative; width: 0.49em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.358em, 1000.27em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-26041" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">1</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-26042" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.49em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.49em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1198"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mn>1</mn>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mn>1</mn>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-1199-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26043" style="width: 2.113em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.49em, 1001.57em, 3.033em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26044"><span class="semantics" id="MathJax-Span-26045"><span class="mrow" id="MathJax-Span-26046"><span class="mrow" id="MathJax-Span-26047"><span class="mfrac" id="MathJax-Span-26048"><span style="display: inline-block; position: relative; width: 1.356em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.033em, 1001.25em, 4.278em, -999.997em); top: -4.705em; left: 50%; margin-left: -0.593em;"><span class="mrow" id="MathJax-Span-26049"><span class="msqrt" id="MathJax-Span-26050"><span style="display: inline-block; position: relative; width: 1.247em; height: 0px;"><span style="position: absolute; clip: rect(3.195em, 1000.49em, 4.169em, -999.997em); top: -4.002em; left: 0.76em;"><span class="mrow" id="MathJax-Span-26051"><span class="mn" id="MathJax-Span-26052" style="font-family: STIXGeneral-Regular;">2</span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.033em, 1000.49em, 3.412em, -999.997em); top: -4.002em; left: 0.76em;"><span style="font-family: STIXGeneral-Regular;">‾</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(2.925em, 1000.76em, 4.169em, -999.997em); top: -3.893em; left: 0em;"><span style="font-family: STIXVariants;">√</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.195em, 1000.49em, 4.169em, -999.997em); top: -3.298em; left: 50%; margin-left: -0.268em;"><span class="mn" id="MathJax-Span-26053" style="font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1001.36em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.356em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.996em; border-left: 0px solid; width: 0px; height: 3.004em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span></div><script type="math/mml" id="MathJax-Element-1199"><math display="block"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>2</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>2</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-1200-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26054" style="width: 2.113em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.49em, 1001.57em, 3.033em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26055"><span class="semantics" id="MathJax-Span-26056"><span class="mrow" id="MathJax-Span-26057"><span class="mrow" id="MathJax-Span-26058"><span class="mfrac" id="MathJax-Span-26059"><span style="display: inline-block; position: relative; width: 1.356em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.033em, 1001.25em, 4.332em, -999.997em); top: -4.705em; left: 50%; margin-left: -0.593em;"><span class="mrow" id="MathJax-Span-26060"><span class="msqrt" id="MathJax-Span-26061"><span style="display: inline-block; position: relative; width: 1.247em; height: 0px;"><span style="position: absolute; clip: rect(3.195em, 1000.44em, 4.169em, -999.997em); top: -4.002em; left: 0.76em;"><span class="mrow" id="MathJax-Span-26062"><span class="mn" id="MathJax-Span-26063" style="font-family: STIXGeneral-Regular;">3</span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.033em, 1000.49em, 3.412em, -999.997em); top: -4.002em; left: 0.76em;"><span style="font-family: STIXGeneral-Regular;">‾</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(2.925em, 1000.76em, 4.169em, -999.997em); top: -3.893em; left: 0em;"><span style="font-family: STIXVariants;">√</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.195em, 1000.49em, 4.169em, -999.997em); top: -3.298em; left: 50%; margin-left: -0.268em;"><span class="mn" id="MathJax-Span-26064" style="font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1001.36em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.356em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.996em; border-left: 0px solid; width: 0px; height: 3.004em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span></div><script type="math/mml" id="MathJax-Element-1200"><math display="block"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>3</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>3</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1201-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mn>1</mn></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mn>1</mn></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26065" style="width: 0.76em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.68em, 1000.44em, 2.654em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-26066"><span class="semantics" id="MathJax-Span-26067"><span class="mrow" id="MathJax-Span-26068"><span class="mn" id="MathJax-Span-26069" style="font-family: STIXGeneral-Regular;">1</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 1.004em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mn>1</mn></mrow><annotation-xml encoding="MathML-Content"><mn>1</mn></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1201"><math display="inline"><semantics><mrow>
#  <mn>1</mn>
# </mrow><annotation-xml encoding="MathML-Content"><mn>1</mn></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-1202-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26070" style="width: 2.113em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.49em, 1001.57em, 3.033em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26071"><span class="semantics" id="MathJax-Span-26072"><span class="mrow" id="MathJax-Span-26073"><span class="mrow" id="MathJax-Span-26074"><span class="mfrac" id="MathJax-Span-26075"><span style="display: inline-block; position: relative; width: 1.356em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.033em, 1001.25em, 4.332em, -999.997em); top: -4.705em; left: 50%; margin-left: -0.593em;"><span class="mrow" id="MathJax-Span-26076"><span class="msqrt" id="MathJax-Span-26077"><span style="display: inline-block; position: relative; width: 1.247em; height: 0px;"><span style="position: absolute; clip: rect(3.195em, 1000.44em, 4.169em, -999.997em); top: -4.002em; left: 0.76em;"><span class="mrow" id="MathJax-Span-26078"><span class="mn" id="MathJax-Span-26079" style="font-family: STIXGeneral-Regular;">3</span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.033em, 1000.49em, 3.412em, -999.997em); top: -4.002em; left: 0.76em;"><span style="font-family: STIXGeneral-Regular;">‾</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(2.925em, 1000.76em, 4.169em, -999.997em); top: -3.893em; left: 0em;"><span style="font-family: STIXVariants;">√</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.195em, 1000.49em, 4.169em, -999.997em); top: -3.298em; left: 50%; margin-left: -0.268em;"><span class="mn" id="MathJax-Span-26080" style="font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1001.36em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.356em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.996em; border-left: 0px solid; width: 0px; height: 3.004em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><msqrt><mn>3</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span></div><script type="math/mml" id="MathJax-Element-1202"><math display="block"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>3</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>3</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-1203-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26081" style="width: 2.113em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.572em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.49em, 1001.57em, 3.033em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26082"><span class="semantics" id="MathJax-Span-26083"><span class="mrow" id="MathJax-Span-26084"><span class="mrow" id="MathJax-Span-26085"><span class="mfrac" id="MathJax-Span-26086"><span style="display: inline-block; position: relative; width: 1.356em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.033em, 1001.25em, 4.278em, -999.997em); top: -4.705em; left: 50%; margin-left: -0.593em;"><span class="mrow" id="MathJax-Span-26087"><span class="msqrt" id="MathJax-Span-26088"><span style="display: inline-block; position: relative; width: 1.247em; height: 0px;"><span style="position: absolute; clip: rect(3.195em, 1000.49em, 4.169em, -999.997em); top: -4.002em; left: 0.76em;"><span class="mrow" id="MathJax-Span-26089"><span class="mn" id="MathJax-Span-26090" style="font-family: STIXGeneral-Regular;">2</span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.033em, 1000.49em, 3.412em, -999.997em); top: -4.002em; left: 0.76em;"><span style="font-family: STIXGeneral-Regular;">‾</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(2.925em, 1000.76em, 4.169em, -999.997em); top: -3.893em; left: 0em;"><span style="font-family: STIXVariants;">√</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.195em, 1000.49em, 4.169em, -999.997em); top: -3.298em; left: 50%; margin-left: -0.268em;"><span class="mn" id="MathJax-Span-26091" style="font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1001.36em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.356em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.996em; border-left: 0px solid; width: 0px; height: 3.004em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><semantics><mrow><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mrow><msqrt><mn>2</mn></msqrt></mrow><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span></div><script type="math/mml" id="MathJax-Element-1203"><math display="block"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>2</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mrow>
#     <msqrt>
#      <mn>2</mn>
#     </msqrt>
#
#    </mrow>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1204-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26092" style="width: 0.923em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.706em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.139em, 1000.71em, 2.708em, -999.997em); top: -2.162em; left: 0em;"><span class="mrow" id="MathJax-Span-26093"><span class="semantics" id="MathJax-Span-26094"><span class="mrow" id="MathJax-Span-26095"><span class="mrow" id="MathJax-Span-26096"><span class="mfrac" id="MathJax-Span-26097"><span style="display: inline-block; position: relative; width: 0.49em; height: 0px; margin-right: 0.111em; margin-left: 0.111em;"><span style="position: absolute; clip: rect(3.358em, 1000.27em, 4.169em, -999.997em); top: -4.435em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-26098" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">1</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(3.358em, 1000.33em, 4.169em, -999.997em); top: -3.623em; left: 50%; margin-left: -0.16em;"><span class="mn" id="MathJax-Span-26099" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">2</span><span style="display: inline-block; width: 0px; height: 4.007em;"></span></span><span style="position: absolute; clip: rect(0.869em, 1000.49em, 1.247em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.49em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.085em;"></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.167em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.568em; border-left: 0px solid; width: 0px; height: 1.861em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></mrow><annotation-xml encoding="MathML-Content"><mrow><mfrac><mn>1</mn><mn>2</mn></mfrac></mrow></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1204"><math display="inline"><semantics><mrow>
#  <mrow>
#   <mfrac>
#    <mn>1</mn>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow>
# </mrow><annotation-xml encoding="MathML-Content"><mrow>
#   <mfrac>
#    <mn>1</mn>
#    <mn>2</mn>
#   </mfrac>
#
#  </mrow></annotation-xml></semantics></math></script></td>
# <td data-align="center"><span class="MathJax_Preview" style="color: inherit;"></span><span class="MathJax" id="MathJax-Element-1205-Frame" tabindex="0" style="position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;inline&quot;><semantics><mrow><mn>0</mn></mrow><annotation-xml encoding=&quot;MathML-Content&quot;><mn>0</mn></annotation-xml></semantics></math>" role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-26100" style="width: 0.76em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.68em, 1000.54em, 2.654em, -999.997em); top: -2.486em; left: 0em;"><span class="mrow" id="MathJax-Span-26101"><span class="semantics" id="MathJax-Span-26102"><span class="mrow" id="MathJax-Span-26103"><span class="mn" id="MathJax-Span-26104" style="font-family: STIXGeneral-Regular;">0</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.492em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 1.075em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="inline"><semantics><mrow><mn>0</mn></mrow><annotation-xml encoding="MathML-Content"><mn>0</mn></annotation-xml></semantics></math></span></span><script type="math/mml" id="MathJax-Element-1205"><math display="inline"><semantics><mrow>
#  <mn>0</mn>
# </mrow><annotation-xml encoding="MathML-Content"><mn>0</mn></annotation-xml></semantics></math></script></td>
# </tr>
# </tbody></table>

# %%
theta = [0, np.pi/6, np.pi/4, np.pi/3, np.pi/2, 2*np.pi/3, 3*np.pi/4, 5*np.pi/6, np.pi]
sin_t = [0, 1/2, np.sqrt(2)/2, np.sqrt(3)/2, 1, np.sqrt(3)/2, np.sqrt(2)/2, 1/2, 0]

x = np.linspace(0,np.pi)
plt.plot(theta, sin_t)
plt.plot(x,np.sin(x))
plt.grid()

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt


plt.rcParams.update({'font.size': 20.0})
plt.rcParams.update({'figure.figsize': (20, 8)})
#plt.rcdefaults() # turn xkcd off

# %%
x = np.linspace(-np.pi, np.pi)

plt.plot(x, np.sin(x), linewidth=2.6, label=r'$f(x) = \sin(x)$')
plt.plot(x, np.cos(x), linewidth=2.6, label=r'$f(x) = \cos(x)$')

# y sqrt
plt.axhline(y=-1,  linewidth=.8, color = 'grey')
plt.axhline(y=-.38, linewidth=.8, color = 'g')
plt.axhline(y=-np.sqrt(2)/2, linewidth=.8, color = 'grey')
plt.axhline(y= 0,            linewidth=.8, color = 'grey')
plt.axhline(y= np.sqrt(2)/2, linewidth=.8, color = 'grey')
plt.axhline(y= 1, linewidth=.8, color = 'grey')

plt.yticks( (-1,  -np.sqrt(2)/2, 0, np.sqrt(2)/2), 
            (r'$-1$', r'$-\frac{\sqrt{2}}{2}$', r'$0$', r'$\frac{\sqrt{2}}{2}$', r'$+1$') )

# x pi
plt.axvline(x=-np.pi,    linewidth=.8, color = 'grey')
plt.axvline(x=-3*np.pi/4,linewidth=.8, color = 'grey')
plt.axvline(x=-np.pi/2,  linewidth=.8, color = 'grey')
plt.axvline(x=-np.pi/4,  linewidth=.8, color = 'grey')

plt.axvline(x=0, linewidth=.8, color = 'grey') 

plt.axvline(x=np.pi/4,  linewidth=.8, color = 'grey')
plt.axvline(x=np.pi/2,  linewidth=.8, color = 'grey')
plt.axvline(x=3*np.pi/4,linewidth=.8, color = 'grey')
plt.axvline(x=np.pi,    linewidth=.8, color = 'grey')

plt.xticks((-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi), 
           (r'$-\pi$', r'$\frac{-3\pi}{4}$', r'$-\pi/2$', r'$-\pi/4$', r'$0$', r'$\pi/4$', r'$\pi/2$', r'$\frac{3\pi}{4}$', r'$\pi$'))

#plt.xkcd()
plt.legend(frameon=False)

# %%
sin = {
          0:  '0',
         .5:  '$\pi/6$',
     0.7071:  '$\pi/4$',
      0.866:  '$\pi/3$',
          1:  '$\pi/2$',
     3.1416:   '0',
}

for v in x:
    v = np.round(v,4)
    mroz = sin.get(v,None)
    if mroz: print(mroz)
# Out:
# 0

# %%
even_squares = [num * num for num in range(11) if num%2 == 0]
even_squares
# Out:
# [0, 4, 16, 36, 64, 100]

# %%
# find number of multiples of pi/2
[round(num%np.pi,3) for num in np.linspace(0, np.pi/2) if num%2 > 0]
# Out:
# [0.032,
#  0.064,
#  0.096,
#  0.128,
#  0.16,
#  0.192,
#  0.224,
#  0.256,
#  0.289,
#  0.321,
#  0.353,
#  0.385,
#  0.417,
#  0.449,
#  0.481,
#  0.513,
#  0.545,
#  0.577,
#  0.609,
#  0.641,
#  0.673,
#  0.705,
#  0.737,
#  0.769,
#  0.801,
#  0.833,
#  0.866,
#  0.898,
#  0.93,
#  0.962,
#  0.994,
#  1.026,
#  1.058,
#  1.09,
#  1.122,
#  1.154,
#  1.186,
#  1.218,
#  1.25,
#  1.282,
#  1.314,
#  1.346,
#  1.378,
#  1.411,
#  1.443,
#  1.475,
#  1.507,
#  1.539,
#  1.571]

# %%
x = np.linspace(0, 2*np.pi)
x = [np.round(x, 5) for x in x]
x = np.asarray(x)
plt.plot(x,np.sin(x))

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951

# %%
np.linspace(0,np.pi,4)
# Out:
# array([0.        , 1.04719755, 2.0943951 , 3.14159265])

# %%
np.pi * 1.04719755
# Out:
# 3.2898681299372297

# %%
def format_func(value, tick_number):
    # find number of multiples of pi/2
    N = int(np.round(2 * value / np.pi))
    
    if N == 0:
        return "0"
    elif N == 1:
        return r"$\pi/2$"
    elif N == 2:
        return r"$\pi$"
    
    elif N % 2 > 0:
        return r"${0}\pi/2$".format(N)
    else:
        return r"${0}\pi$".format(N // 2)

# %%
import matplotlib.pyplot as plt
import numpy as np

from basic_units import radians, degrees, cos, sin

#x = [val*radians for val in np.arange(0, 15, 0.01)]
x = [val*radians for val in np.linspace(0, 5*np.pi)]

fig, axs = plt.subplots(2)

axs[0].plot(x, cos(x), xunits=radians)
axs[0].plot(x, sin(x), xunits=radians)

axs[1].plot(x, cos(x), xunits=degrees)

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-127-f365bcfea6d6> in <module>
#       2 import numpy as np
#       3
# ----> 4 from basic_units import radians, degrees, cos, sin
#       5
#       6 #x = [val*radians for val in np.arange(0, 15, 0.01)]
#
# ImportError: cannot import name 'sin' from 'basic_units' (/app/pysnippets/basic_units.py)

# %% [markdown]
# # force it by plotting the index of each x-value and then setting the ticks to the data points:

# %%
x = [0.00001,0.001,0.01,0.1,0.5,1,5]
# create an index for each tick position
xi = list(range(len(x)))
y = [0.945,0.885,0.893,0.9,0.996,1.25,1.19]
plt.ylim(0.8,1.4)
# plot the index for the x-values
plt.plot(xi, y, marker='o', linestyle='--', color='r', label='Square') 
plt.xlabel('x')
plt.ylabel('y') 
plt.xticks(xi, x)
plt.title('compare')
plt.legend() 
plt.show()
# Out:
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
