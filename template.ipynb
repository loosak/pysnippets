# %%
# %pip install --upgrade pip
# %pip install vega_datasets
# Out:
# Collecting pip
#   Downloading pip-20.2.2-py2.py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 8.3 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.0.2
#     Uninstalling pip-20.0.2:
#       Successfully uninstalled pip-20.0.2
# Successfully installed pip-20.2.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: vega_datasets in /usr/local/lib/python3.8/site-packages (0.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/site-packages (from vega_datasets) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/site-packages (from pandas->vega_datasets) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.8/site-packages (from pandas->vega_datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.8/site-packages (from pandas->vega_datasets) (2019.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas->vega_datasets) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# ?print
# Out:
# Docstring:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %% [markdown]
# #  Shortcuts to speed up your work.
# https://florianwilhelm.info/2018/11/working_efficiently_with_jupyter_lab/
#
# <table class="table table-condensed table-bordered">
# <thead>
# <tr>
# <th>Command</th>
# <th>Shortcut</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Split Cell</td>
# <td><kbd>Ctrl</kbd> <kbd>Shift</kbd> <kbd>-</kbd></td>
# </tr>
# <tr>
# <td>Enter Command Mode</td>
# <td><kbd>Esc</kbd></td>
# </tr>
# <tr>
# <td>Run Cell</td>
# <td><kbd>Ctrl</kbd> <kbd>Enter</kbd></td>
# </tr>
# <tr>
# <td>Run Cell <span class="amp">&amp;</span> Select Next</td>
# <td><kbd>Shift</kbd> <kbd>Enter</kbd></td>
# </tr>
# <tr>
# <td>Add Cell Above/Below</td>
# <td><kbd>A</kbd> / <kbd>B</kbd></td>
# </tr>
# <tr>
# <td>Copy/Cut/Paste Cell</td>
# <td><kbd>C</kbd> / <kbd>X</kbd> / <kbd>V</kbd></td>
# </tr>
# <tr>
# <td>Look Around Up/Down</td>
# <td><kbd>Alt</kbd> <kbd>⇧</kbd> / <kbd>⇩</kbd></td>
# </tr>
# <tr>
# <td>Markdown Cell</td>
# <td><kbd>M</kbd></td>
# </tr>
# <tr>
# <td>Code Cell</td>
# <td><kbd>Y</kbd></td>
# </tr>
# <tr>
# <td>Delete Cell Output</td>
# <td><kbd>M</kbd>, <kbd>Y</kbd> (workaround)</td>
# </tr>
# <tr>
# <td>Delete Cell</td>
# <td><kbd>D</kbd> <kbd>D</kbd></td>
# </tr>
# <tr>
# <td>Toggle Line Numbers</td>
# <td><kbd>Shift</kbd> <kbd>L</kbd></td>
# </tr>
# <tr>
# <td>Comment Line</td>
# <td><kbd>Ctrl</kbd> <kbd>/</kbd></td>
# </tr>
# <tr>
# <td>Command Palette</td>
# <td><kbd>Accel</kbd> <kbd>Shift</kbd> <kbd>C</kbd></td>
# </tr>
# <tr>
# <td>File Explorer</td>
# <td><kbd>Accel</kbd> <kbd>Shift</kbd> <kbd>F</kbd></td>
# </tr>
# <tr>
# <td>Toggle Bar</td>
# <td><kbd>Accel</kbd> <kbd>B</kbd></td>
# </tr>
# <tr>
# <td>Fullscreen Mode</td>
# <td><kbd>Accel</kbd> <kbd>Shift</kbd> <kbd>D</kbd></td>
# </tr>
# <tr>
# <td>Close Tab</td>
# <td><kbd>Ctrl</kbd> <kbd>Q</kbd></td>
# </tr>
# <tr>
# <td>Launcher</td>
# <td><kbd>Accel</kbd> <kbd>Shift</kbd> <kbd>L</kbd></td>
# </tr>
# </tbody>
# </table>

# %%
import sys
import logging
import dateutil as dt

import numpy as np
import scipy as sp
import sklearn
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
mpl.style.use('seaborn')

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("whitegrid")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

logging.basicConfig(level=logging.INFO, format='%(asctime)s [%(levelname)7s] %(message)s', stream=sys.stdout)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s [%(levelname)7s] %(message)s', stream=sys.stdout)

# %%
X = np.linspace(-5*np.pi, 5*np.pi, 1024)
Y = np.sinc(X)
plt.plot(X, np.sinc(X), c = 'k');

# %%
from vega_datasets import data
stock = data.stocks()
stock.info()
stock.pivot(index='date', columns='symbol', values='price').plot();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  560 non-null    object
#  1   date    560 non-null    datetime64[ns]
#  2   price   560 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 13.2+ KB

# %% [markdown]
# # Access a cell’s result

# %%
np.pi
# Out:
# 3.141592653589793

# %%
result = _29
result
# Out:
# 3.141592653589793
