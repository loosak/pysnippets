# %% [markdown]
# # Alerts

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize': (14, 10),})

# %%
df = pd.read_csv('alerts.2020.07.csv', sep=',')
df['Time'] = pd.to_datetime(df['Occurrence Time'])
df.drop(columns=['Occurrence Time','Alert Name', 'Severity', 'Alert Source'], inplace=True)
df['Day'] = df['Time'].apply(lambda x: pd.Timestamp.to_pydatetime(x).strftime("%A"))

df.Violation = df.Violation.str.strip(' ms/op')
df.drop(df[df.Violation == 'Warning'].index.values.tolist(),inplace=True)
df.Violation = pd.to_numeric(df.Violation)
#df.Violation = df.Violation.apply(lambda x: float(x))

df = df[(df['Time'] > dt.datetime(2020,7,1))] # last month
df.Violation = df.Violation.apply(lambda x: float(x))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 797 entries, 892 to 1689
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Condition          797 non-null    object
#  1   Violation          797 non-null    float64
#  2   Resource           797 non-null    object
#  3   Internal Resource  797 non-null    object
#  4   Time               797 non-null    datetime64[ns]
#  5   Day                797 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 43.6+ KB

# %%
df[df.Violation > 1.8]
# Out:
#        Condition  Violation             Resource     Internal Resource  \
# 910   >= 1 ms/op       1.87  CH-IBM.2107-75KBD21             FB_pool_1
# 911   >= 1 ms/op       1.92  CH-IBM.2107-75KBD21             FB_pool_0
# 926   >= 1 ms/op       2.00  CH-IBM.2107-75KBD21             FB_pool_1
# 927   >= 1 ms/op       1.85  CH-IBM.2107-75KBD21             FB_pool_0
# 930   >= 1 ms/op       2.52  CH-IBM.2107-75KBD21             FB_pool_0
# ...          ...        ...                  ...                   ...
# 1685  >= 5 ms/op       6.11  CH-IBM.2107-75KBD21  czas0134_s_1915_1915
# 1686  >= 5 ms/op       5.46  CH-IBM.2107-75KBD21  czas0134_s_1908_1908
# 1687  >= 5 ms/op       5.69  CH-IBM.2107-75KBD21  czas0134_s_1812_1812
# 1688  >= 5 ms/op       5.74  CH-IBM.2107-75KBD21  czas0134_s_1907_1907
# 1689  >= 5 ms/op       5.56  CH-IBM.2107-75KBD21  czas0134_s_1902_1902
#
#                     Time        Day
# 910  2020-07-04 08:38:23   Saturday
# 911  2020-07-04 08:38:23   Saturday
# 926  2020-07-05 10:38:23     Sunday
# 927  2020-07-05 10:38:23     Sunday
# 930  2020-07-05 11:00:23     Sunday
# ...                  ...        ...
# 1685 2020-07-29 21:28:25  Wednesday
# 1686 2020-07-29 21:28:25  Wednesday
# 1687 2020-07-29 21:28:25  Wednesday
# 1688 2020-07-29 21:28:25  Wednesday
# 1689 2020-07-29 21:30:24  Wednesday
#
# [726 rows x 6 columns]

# %% [markdown]
# # Check for HVG

# %%
df[~(df.Resource == 'CH-IBM.2107-75KBD21')]
# Out:
# Empty DataFrame
# Columns: [Condition, Violation, Resource, Internal Resource, Time, Day]
# Index: []

# %% [markdown]
# # Volumes

# %%
df[~(df['Internal Resource'] == 'FB_pool_0') & ~(df['Internal Resource'] == 'FB_pool_1')]
# Out:
#        Condition   Violation             Resource     Internal Resource  \
# 932   >= 5 ms/op  5.81 ms/op  CH-IBM.2107-75KBD21  czas0005_i_1048_1048
# 935   >= 5 ms/op  5.69 ms/op  CH-IBM.2107-75KBD21  czas0005_i_1013_1013
# 936   >= 5 ms/op  6.33 ms/op  CH-IBM.2107-75KBD21  czas0005_i_1165_1165
# 937   >= 5 ms/op  5.19 ms/op  CH-IBM.2107-75KBD21  czas0005_i_1055_1055
# 938   >= 5 ms/op  6.36 ms/op  CH-IBM.2107-75KBD21  czas0005_i_1048_1048
# ...          ...         ...                  ...                   ...
# 1685  >= 5 ms/op  6.11 ms/op  CH-IBM.2107-75KBD21  czas0134_s_1915_1915
# 1686  >= 5 ms/op  5.46 ms/op  CH-IBM.2107-75KBD21  czas0134_s_1908_1908
# 1687  >= 5 ms/op  5.69 ms/op  CH-IBM.2107-75KBD21  czas0134_s_1812_1812
# 1688  >= 5 ms/op  5.74 ms/op  CH-IBM.2107-75KBD21  czas0134_s_1907_1907
# 1689  >= 5 ms/op  5.56 ms/op  CH-IBM.2107-75KBD21  czas0134_s_1902_1902
#
#                     Time        Day
# 932  2020-07-05 11:01:24     Sunday
# 935  2020-07-05 11:15:23     Sunday
# 936  2020-07-05 11:15:23     Sunday
# 937  2020-07-05 11:15:23     Sunday
# 938  2020-07-05 11:15:23     Sunday
# ...                  ...        ...
# 1685 2020-07-29 21:28:25  Wednesday
# 1686 2020-07-29 21:28:25  Wednesday
# 1687 2020-07-29 21:28:25  Wednesday
# 1688 2020-07-29 21:28:25  Wednesday
# 1689 2020-07-29 21:30:24  Wednesday
#
# [690 rows x 6 columns]

# %%
# Pool1

# %%
pdf = df[df['Internal Resource'] == 'FB_pool_1']
pdf = pdf[df.Violation > 1.8]
#pdf.reset_index(inplace=True)
pdf.set_index('Time', inplace=True)
print(f'Output {pdf.shape[0]} rows')
pdf[['Day', 'Violation']]
# Out:
# Output 18 rows
# <ipython-input-125-2a10d2d088d0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pdf = pdf[df.Violation > 1.8]
#                           Day  Violation
# Time
# 2020-07-04 08:38:23  Saturday       1.87
# 2020-07-05 10:38:23    Sunday       2.00
# 2020-07-05 11:00:23    Sunday       2.51
# 2020-07-05 11:11:23    Sunday       2.57
# 2020-07-05 11:22:23    Sunday       1.92
# 2020-07-05 12:20:24    Sunday       5.75
# 2020-07-11 10:44:22  Saturday       3.71
# 2020-07-11 10:55:25  Saturday       3.54
# 2020-07-11 13:10:24  Saturday       1.81
# 2020-07-12 10:15:23    Sunday       2.19
# 2020-07-12 10:37:24    Sunday       3.43
# 2020-07-12 10:48:25    Sunday       2.16
# 2020-07-12 10:59:25    Sunday       3.15
# 2020-07-19 10:28:26    Sunday       1.97
# 2020-07-19 10:50:23    Sunday       4.14
# 2020-07-26 10:12:22    Sunday       2.32
# 2020-07-26 10:27:22    Sunday       2.69
# 2020-07-26 10:50:22    Sunday       8.96

# %%
# Working days

wdf = df[~(df['Day'] == 'Saturday') & ~(df['Day'] == 'Sunday')]
wdf.set_index('Time', inplace=True)

# %%
wdf[~(wdf.Day == 'Wednesday')][['Day', 'Violation', 'Internal Resource']]
# Out:
#                          Day  Violation     Internal Resource
# Time
# 2020-07-06 22:37:23   Monday       6.60  czas0134_s_1903_1903
# 2020-07-06 22:37:23   Monday       6.40  czas0134_s_180C_180c
# 2020-07-06 22:37:23   Monday       6.48  czas0134_s_180A_180a
# 2020-07-06 22:37:23   Monday       5.63  czas0134_s_180B_180b
# 2020-07-06 22:37:23   Monday       6.50  czas0134_s_1907_1907
# ...                      ...        ...                   ...
# 2020-07-21 23:38:25  Tuesday       5.40  czas0134_s_1816_1816
# 2020-07-21 23:39:24  Tuesday       5.11  czas0134_s_1901_1901
# 2020-07-21 23:39:24  Tuesday       5.27  czas0134_s_180C_180c
# 2020-07-21 23:39:24  Tuesday       5.43  czas0134_s_180B_180b
# 2020-07-21 23:39:24  Tuesday       5.35  czas0134_s_1802_1802
#
# [149 rows x 3 columns]

# %%
wdf[(wdf.Day == 'Monday')].describe()
# Out:
#        Violation
# count  44.000000
# mean    5.761818
# std     0.545899
# min     5.020000
# 25%     5.352500
# 50%     5.680000
# 75%     6.000000
# max     7.110000

# %%
wdf[(wdf.Day == 'Wednesday')][['Day', 'Violation', 'Internal Resource']]
# Out:
#                            Day  Violation     Internal Resource
# Time
# 2020-07-29 21:00:24  Wednesday       5.72  czas0134_s_1910_1910
# 2020-07-29 21:00:24  Wednesday       5.36  czas0134_s_1904_1904
# 2020-07-29 21:00:24  Wednesday       5.01  czas0134_s_1808_1808
# 2020-07-29 21:00:24  Wednesday       5.68  czas0134_s_1805_1805
# 2020-07-29 21:00:24  Wednesday       5.09  czas0134_s_1811_1811
# ...                        ...        ...                   ...
# 2020-07-29 21:28:25  Wednesday       6.11  czas0134_s_1915_1915
# 2020-07-29 21:28:25  Wednesday       5.46  czas0134_s_1908_1908
# 2020-07-29 21:28:25  Wednesday       5.69  czas0134_s_1812_1812
# 2020-07-29 21:28:25  Wednesday       5.74  czas0134_s_1907_1907
# 2020-07-29 21:30:24  Wednesday       5.56  czas0134_s_1902_1902
#
# [120 rows x 3 columns]

# %%
wdf[(wdf.Day == 'Monday') & (wdf.Violation > 6.4)][['Day', 'Violation', 'Internal Resource']]
# Out:
#                         Day  Violation     Internal Resource
# Time
# 2020-07-06 22:37:23  Monday       6.60  czas0134_s_1903_1903
# 2020-07-06 22:37:23  Monday       6.48  czas0134_s_180A_180a
# 2020-07-06 22:37:23  Monday       6.50  czas0134_s_1907_1907
# 2020-07-06 22:37:23  Monday       6.54  czas0134_s_1809_1809
# 2020-07-06 22:37:23  Monday       6.47  czas0134_s_1906_1906
# 2020-07-06 22:59:26  Monday       6.82  czas0134_s_1800_1800
# 2020-07-06 23:01:29  Monday       7.11  czas0134_s_1802_1802
# 2020-07-06 23:01:29  Monday       6.54  czas0134_s_1914_1914
# 2020-07-06 23:01:29  Monday       6.62  czas0134_s_180C_180c

# %%
wdf[(wdf.Day == 'Tuesday') & (wdf.Violation > 6.16)][['Day', 'Violation', 'Internal Resource']]
# Out:
#                          Day  Violation     Internal Resource
# Time
# 2020-07-21 20:27:23  Tuesday       6.23  czas0134_s_1805_1805
# 2020-07-21 20:28:24  Tuesday       6.55  czas0134_s_190C_190c
# 2020-07-21 20:43:24  Tuesday       7.38  czas0134_s_190E_190e
# 2020-07-21 20:43:24  Tuesday       6.36  czas0134_s_190B_190b
# 2020-07-21 20:43:24  Tuesday       7.28  czas0134_s_1914_1914
# 2020-07-21 20:43:24  Tuesday       6.42  czas0134_s_1810_1810
# 2020-07-21 20:43:24  Tuesday       6.39  czas0134_s_180F_180f
# 2020-07-21 20:43:24  Tuesday       6.23  czas0134_s_190A_190a
# 2020-07-21 23:34:23  Tuesday       6.25  czas0134_s_1900_1900

# %%
wdf[(wdf.Day == 'Wednesday') & (wdf.Violation > 6.7)][['Day', 'Violation', 'Internal Resource']]
# Out:
#                            Day  Violation     Internal Resource
# Time
# 2020-07-29 21:11:28  Wednesday       6.84  czas0134_s_1902_1902
# 2020-07-29 21:11:28  Wednesday       6.93  czas0134_s_1806_1806
# 2020-07-29 21:11:28  Wednesday       6.76  czas0134_s_190A_190a
# 2020-07-29 21:11:28  Wednesday       7.71  czas0134_s_190C_190c
# 2020-07-29 21:11:28  Wednesday       7.27  czas0134_s_1914_1914
# 2020-07-29 21:11:28  Wednesday       8.00  czas0134_s_180A_180a
# 2020-07-29 21:11:28  Wednesday       7.13  czas0134_s_1911_1911

# %%
wdf[~(wdf.Day == 'Wednesday') & ~(wdf.Day == 'Monday')  & ~(wdf.Day == 'Tuesday') ]
# Out:
# Empty DataFrame
# Columns: [Condition, Violation, Resource, Internal Resource, Day]
# Index: []

# %%
pdf[][['Time', 'Day', 'Violation']]

# %%
df['match'] = df.col1.eq(df.col1.shift())
df['match'] = df.col1 == df.col1.shift()

# slicing
def comp_prev(a):
    return np.concatenate(([False],a[1:] == a[:-1]))

df['match'] = comp_prev(df.col1.values)

# %%
'Saturday' 'Sunday'

# %%
np.datetime64('2015-05-17')
# Out:
# numpy.datetime64('2015-05-17')

# %%
('2014-01-23 00:00:00', tz=None).to_pydatetime()
# Out:
# datetime.datetime(2014, 1, 23, 0, 0)

# %%
np.datetime64('2020-05-09 06:42:22')
# Out:
# numpy.datetime64('2020-05-09T06:42:22')

# %%
dt.datetime(2020,5,1)
# Out:
# datetime.datetime(2020, 5, 1, 0, 0)
